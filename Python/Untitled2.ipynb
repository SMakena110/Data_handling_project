# %% [markdown]
# #### REPORT ON THE ESTIMATION OF OBESITY LEVELS BASED ON DIETARY AND PHYSICAL HABITS
#
#
# 1. **Data Preparation** :The dataset contained 2,111 records across 17 features, including demographic, physical, dietary, and activity data. Key steps in preparing the data were:
# - **Completeness**: All fields had non-null values.
# - **Data Cleaning**: Duplicate entries (42 records) were removed, leaving 2,069 clean records. Inconsistent column naming conventions were standardized.
# - **Handling Outliers**: Weight outliers were addressed through capping between the 15th and 85th percentiles, normalizing weight distribution.
# - **Normalization:** Continuous variables (age, weight, height, physical activity frequency, etc.) were normalized using Min-Max Scaling to facilitate model performance and feature comparability. Encoding: Categorical variables were encoded into numerical formats using LabelEncoder for compatibility with machine learning algorithms.
#
# 2. **Overview of Data Exploration Statistics and Trends**
# - **
# Demographic**s: The collection was dominated by younger people, with normalized age values centered around 0.2. Bimodality of the weight distribution, with maxima for obese and underweight/normal-weight people, indicates a polarized dataset.- **
# Distribution of Heig**ht: Clustering was probably impacted by age, gender, or ethnicity- **.
# Food Routi**n s:
# The high frequency of vegetable consumption suggested health-conscious behavio- **rs.
# Meal Pat**terns: It was rare for people to nibble in between meals; most people ate three meals a - **day.
# Water **Intake: The average person drank two liters every- ** day.
# Physical A**ctivity: Sedentary people were distinguished from groups that were moderately active by a bimodal distrib- **ution.
# Techno**logy Use: There was a sizable fraction that used technology moderately, and higher physical activity was associated with lower t
# - **Transportation**: Using a car was linked to heavier weights, but active modes like walking or cycling were linked to healthier weights.
# - **
# The correlation**:
# There was a significant positive connection between height and weight (0.6–0.7).
# There was a considerable correlation between the amount of time spent exercising and its frequenc- **y.
# Connections to Obesity Le**: els
# Obesity levels were linked to high-calorie meals and family history.
# Although outliers continued to occur among calorie-tracking people, calorie monitoring demonstrated a protective effect.
# The effects of alcohol intake were varied, with moderate drinkers showing more balanced weights than regular or abstinent dr
#
# 3. **Understanding how dietary practices affect obesity**:
#
# Obesity is closely associated with high-calorie meals, but risks are reduced by regular vegetable eating and sufficient water intake.
# Unusual snacking and eating habits lead to weight gai- **n.
# Lifestyle and Physical Acti**v y:
#
# One of the main causes of obesity is sedentary lifestyles, which include little exercise and excessive tech use.
# Walking, cycling, and other active transportation techniques support the maintenance of healthy we- **ights.
# Behavior and Environmental**  ctors:
#
# Obesity rates are influenced by family history and socioeconomic factors, including mode of transportation and alc- **ohol use.
# Trends**   Obesity:
#
# A significant number of people fit into high-obesity categories, indicating structural problems with nutrition a
#
# 4. **Suggestions for Public Health Initiatives**:
#
# Encourage the eating of more vegetables and fewer calorie-dense items in balanced diets.
# Increase knowledge about drinking enough water as an affordable way to reduce obesity.
# Initiatives for Physical Activity:
#
# Promote the use of active transportation and incorporate exercise into everyday activities.
# Encourage inactive people to take up moderate exercise by offering incentives.
# Sedentary behavior and technology:
#
# Encourage less time spent on screens and active breaks when engaging in sedentary pursuits.
# Urban planning and policy:
#
# Encourage urban design that promotes active transportation, such as bike lanes.
# Put limits or taxes on items that are high in calories but low
# - **Tailored Interventions**:
#
# Offer specialized interventions to people who have a family history of obesity or certain eating habits.
# Observation and Investigation:
#
# Monitor changes in obesity measures at the population level to assess the efficacy of interventions.
# Do further research on how culture affects eating patterns and obesity.
# 5. Assessment of the Model
# With a test accuracy of 93%, Random Forest outpelformed Lrgistic Regression (74%).
# Dietary practices, physical activity, and demographic characteristics were identified as the main predictors of obesity by feature importance.
# The complex nature of obesity was emphasized by both models; nevertheless, additional refinement and cross-validation are suggested to improve general
#  in nutrients.
#
#
# nd lifestyle.
#
#
# inkers.
#
# ech use.
